# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Load the Generic Dataset
generic_dataset = pd.read_csv("Generic_Dataset.csv")

# Preprocess Generic Dataset
X_generic = generic_dataset.iloc[:, :20].values
y_generic = generic_dataset.iloc[:, 20].values

# Encode labels
label_encoder_generic = LabelEncoder()
y_generic_encoded = label_encoder_generic.fit_transform(y_generic)

# Split the data into training and testing sets
X_generic_train, X_generic_test, y_generic_train, y_generic_test = train_test_split(
    X_generic, y_generic_encoded, test_size=0.2, random_state=42
)

# Build and train the first AI model
model_generic = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(20,)),
    tf.keras.layers.Dense(80, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1, activation='softmax')  # Adjust the number of classes
])

model_generic.compile(optimizer='adamax', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_generic.fit(X_generic_train, y_generic_train, epochs=5, validation_data=(X_generic_test, y_generic_test))

# Save the model for future use
model_generic.save("model_generic.h5")

# Load the first dataset for parallel AI 1
data_1 = pd.read_csv("data_1.csv")

# Preprocess data_1
X_data_1 = data_1.iloc[:, :14].values
y_data_1 = data_1.iloc[:, 14].values

# Encode labels if needed
label_encoder_data_1 = LabelEncoder()
y_data_1_encoded = label_encoder_data_1.fit_transform(y_data_1)

# Build and train the first parallel AI model
model_parallel_1 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(14,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_1.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_1.fit(X_data_1, y_data_1_encoded, epochs=100)

# Save the model for future use
model_parallel_1.save("model_parallel_1.h5")

# Load the second dataset for parallel AI 2
data_2 = pd.read_csv("data_2.csv")

# Preprocess data_2
X_data_2 = data_2.iloc[:, :5].values
y_data_2 = data_2.iloc[:, 5].values

# Encode labels if needed
label_encoder_data_2 = LabelEncoder()
y_data_2_encoded = label_encoder_data_2.fit_transform(y_data_2)

# Build and train the second parallel AI model
model_parallel_2 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(5,)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')  # Adjust the number of classes
])

model_parallel_2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model_parallel_2.fit(X_data_2, y_data_2_encoded, epochs=50)

# Save the model for future use
model_parallel_2.save("model_parallel_2.h5")

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
output_parallel_1 = model_parallel_1.predict(X_data_1)
output_parallel_2 = model_parallel_2.predict(X_data_2)

# Choose the minimum number of rows for concatenation
min_rows = min(output_parallel_1.shape[0], output_parallel_2.shape[0])

# Subset the outputs to have the same number of rows
output_parallel_1 = output_parallel_1[:min_rows]
output_parallel_2 = output_parallel_2[:min_rows]

# Concatenate the outputs
combined_output = tf.keras.layers.Concatenate()([output_parallel_1, output_parallel_2])

# Convert to Pandas DataFrames
output_df1 = pd.DataFrame(output_parallel_1)
output_df2 = pd.DataFrame(output_parallel_2)

# Save combined outputs to CSV
output_df1.to_csv("data_watch1.csv", index=False)
output_df2.to_csv("data_watch2.csv", index=False)

# Convert parallel AI 1 output to a single column (scaling down)
scaled_output_parallel_1 = output_parallel_1.argmax(axis=1)

# Convert parallel AI 2 output to a single column (scaling down)
scaled_output_parallel_2 = output_parallel_2.argmax(axis=1)

# Save scaled outputs along with labels to CSV
scaled_output_df1 = pd.DataFrame({'label': y_data_1_encoded[:min_rows], 'scaled_output': scaled_output_parallel_1})
scaled_output_df1.to_csv("scaled_output1.csv", index=False)

scaled_output_df2 = pd.DataFrame({'label': y_data_2_encoded[:min_rows], 'scaled_output': scaled_output_parallel_2})
scaled_output_df2.to_csv("scaled_output2.csv", index=False)

# Save the combined output to CSV
combined_output_df = pd.DataFrame(combined_output.numpy())
combined_output_df.to_csv("combined_output.csv", index=False)

# Define num_classes_data_3 after combining outputs
num_classes_data_3 = 4  # Replace with the actual number of classes for the third dataset

# Build and train the third AI model
model_combined = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(combined_output.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes_data_3, activation='softmax')  # Adjust the number of classes
])

# Load the third dataset for the final AI
data_3 = pd.read_csv("generated_data1.csv")

# Preprocess data_3
X_data_3 = data_3.iloc[:, :-1].values
y_data_3 = data_3.iloc[:, -1].values

# Encode labels if needed
label_encoder_data_3 = LabelEncoder()
y_data_3_encoded = label_encoder_data_3.fit_transform(y_data_3)

# Compile the model
model_combined.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model using only the third dataset
model_combined.fit(X_data_3, y_data_3_encoded, epochs=100, validation_split=0.2)

# Save the output of the final AI to CSV
final_output = model_combined.predict(X_data_3)
final_output_df = pd.DataFrame(final_output)
final_output_df.to_csv("final_output.csv", index=False)  # Save final output to "final_output.csv"

# Save the model for future use
model_combined.save("model_combined.h5")
# Out:
# Epoch 1/5
# 1/1 [==============================] - 1s 620ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/5
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/5
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/5
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/5
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 1/100
# c:\Users\Mayank Jaiswal\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2/2 [==============================] - 1s 6ms/step - loss: 1.3792 - accuracy: 0.3000
# Epoch 2/100
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3511 - accuracy: 0.4833
# Epoch 3/100
# 2/2 [==============================] - 0s 10ms/step - loss: 1.3230 - accuracy: 0.5000
# Epoch 4/100
# 2/2 [==============================] - 0s 4ms/step - loss: 1.3025 - accuracy: 0.5333
# Epoch 5/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2825 - accuracy: 0.5167
# Epoch 6/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2614 - accuracy: 0.5167
# Epoch 7/100
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2421 - accuracy: 0.5500
# Epoch 8/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2234 - accuracy: 0.5500
# Epoch 9/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2027 - accuracy: 0.5667
# Epoch 10/100
# 2/2 [==============================] - 0s 5ms/step - loss: 1.1832 - accuracy: 0.5667
# Epoch 11/100
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1617 - accuracy: 0.5667
# Epoch 12/100
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1403 - accuracy: 0.5667
# Epoch 13/100
# 2/2 [==============================] - 0s 3ms/step - loss: 1.1177 - accuracy: 0.6167
# Epoch 14/100
# 2/2 [==============================] - 0s 2ms/step - loss: 1.0952 - accuracy: 0.6000
# Epoch 15/100
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0726 - accuracy: 0.6333
# Epoch 16/100
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0487 - accuracy: 0.6500
# Epoch 17/100
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0253 - accuracy: 0.6500
# Epoch 18/100
# 2/2 [==============================] - 0s 3ms/step - loss: 1.0008 - accuracy: 0.7167
# Epoch 19/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.9751 - accuracy: 0.7167
# Epoch 20/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9492 - accuracy: 0.7000
# Epoch 21/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9241 - accuracy: 0.7500
# Epoch 22/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8981 - accuracy: 0.7833
# Epoch 23/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8723 - accuracy: 0.8167
# Epoch 24/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8475 - accuracy: 0.8167
# Epoch 25/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8221 - accuracy: 0.8167
# Epoch 26/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7965 - accuracy: 0.8167
# Epoch 27/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7732 - accuracy: 0.8167
# Epoch 28/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7489 - accuracy: 0.8333
# Epoch 29/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7256 - accuracy: 0.8500
# Epoch 30/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7050 - accuracy: 0.8333
# Epoch 31/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6835 - accuracy: 0.8333
# Epoch 32/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6621 - accuracy: 0.8667
# Epoch 33/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6440 - accuracy: 0.8833
# Epoch 34/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6241 - accuracy: 0.8833
# Epoch 35/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6042 - accuracy: 0.8667
# Epoch 36/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5859 - accuracy: 0.8667
# Epoch 37/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5689 - accuracy: 0.8667
# Epoch 38/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5531 - accuracy: 0.8667
# Epoch 39/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5387 - accuracy: 0.8667
# Epoch 40/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5246 - accuracy: 0.8667
# Epoch 41/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5076 - accuracy: 0.8833
# Epoch 42/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4940 - accuracy: 0.8833
# Epoch 43/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.8833
# Epoch 44/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4676 - accuracy: 0.8833
# Epoch 45/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4547 - accuracy: 0.8833
# Epoch 46/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4442 - accuracy: 0.8833
# Epoch 47/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4333 - accuracy: 0.9000
# Epoch 48/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4219 - accuracy: 0.9000
# Epoch 49/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4116 - accuracy: 0.9167
# Epoch 50/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4011 - accuracy: 0.9167
# Epoch 51/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3918 - accuracy: 0.9167
# Epoch 52/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3818 - accuracy: 0.9167
# Epoch 53/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.9167
# Epoch 54/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3643 - accuracy: 0.9167
# Epoch 55/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3554 - accuracy: 0.9167
# Epoch 56/100
# 2/2 [==============================] - 0s 15ms/step - loss: 0.3480 - accuracy: 0.9167
# Epoch 57/100
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3391 - accuracy: 0.9167
# Epoch 58/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3309 - accuracy: 0.9167
# Epoch 59/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3231 - accuracy: 0.9167
# Epoch 60/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.9167
# Epoch 61/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3089 - accuracy: 0.9167
# Epoch 62/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3027 - accuracy: 0.9167
# Epoch 63/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2958 - accuracy: 0.9167
# Epoch 64/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2890 - accuracy: 0.9167
# Epoch 65/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2827 - accuracy: 0.9167
# Epoch 66/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2766 - accuracy: 0.9333
# Epoch 67/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2714 - accuracy: 0.9500
# Epoch 68/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2659 - accuracy: 0.9500
# Epoch 69/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2601 - accuracy: 0.9500
# Epoch 70/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2546 - accuracy: 0.9500
# Epoch 71/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2484 - accuracy: 0.9500
# Epoch 72/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2438 - accuracy: 0.9667
# Epoch 73/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2383 - accuracy: 0.9667
# Epoch 74/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2343 - accuracy: 0.9667
# Epoch 75/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2287 - accuracy: 0.9667
# Epoch 76/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2235 - accuracy: 0.9667
# Epoch 77/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2196 - accuracy: 0.9667
# Epoch 78/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2145 - accuracy: 0.9667
# Epoch 79/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2099 - accuracy: 0.9667
# Epoch 80/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.9667
# Epoch 81/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2030 - accuracy: 0.9667
# Epoch 82/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1969 - accuracy: 0.9667
# Epoch 83/100
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1930 - accuracy: 0.9667
# Epoch 84/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9667
# Epoch 85/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1852 - accuracy: 0.9667
# Epoch 86/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1816 - accuracy: 0.9667
# Epoch 87/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1775 - accuracy: 0.9667
# Epoch 88/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1738 - accuracy: 0.9667
# Epoch 89/100
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1700 - accuracy: 0.9667
# Epoch 90/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1669 - accuracy: 0.9667
# Epoch 91/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9667
# Epoch 92/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1603 - accuracy: 0.9667
# Epoch 93/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1564 - accuracy: 0.9667
# Epoch 94/100
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1537 - accuracy: 0.9667
# Epoch 95/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1502 - accuracy: 0.9667
# Epoch 96/100
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1477 - accuracy: 0.9667
# Epoch 97/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1443 - accuracy: 0.9667
# Epoch 98/100
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1417 - accuracy: 0.9833
# Epoch 99/100
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1381 - accuracy: 0.9833
# Epoch 100/100
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9833
# Epoch 1/50
# c:\Users\Mayank Jaiswal\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 1s 4ms/step - loss: 1.3644 - accuracy: 0.2900
# Epoch 2/50
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3319 - accuracy: 0.5750
# Epoch 3/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.3095 - accuracy: 0.4850
# Epoch 4/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2870 - accuracy: 0.4700
# Epoch 5/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2614 - accuracy: 0.6350
# Epoch 6/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2338 - accuracy: 0.9600
# Epoch 7/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2055 - accuracy: 0.9900
# Epoch 8/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1729 - accuracy: 0.9900
# Epoch 9/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1379 - accuracy: 0.9900
# Epoch 10/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.1012 - accuracy: 0.9900
# Epoch 11/50
# 7/7 [==============================] - 0s 1ms/step - loss: 1.0687 - accuracy: 0.9900
# Epoch 12/50
# 7/7 [==============================] - 0s 2ms/step - loss: 1.0256 - accuracy: 0.9900
# Epoch 13/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9878 - accuracy: 0.9700
# Epoch 14/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.9409 - accuracy: 0.9900
# Epoch 15/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8949 - accuracy: 0.9900
# Epoch 16/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8525 - accuracy: 0.9900
# Epoch 17/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8076 - accuracy: 0.9900
# Epoch 18/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.7587 - accuracy: 0.9900
# Epoch 19/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.7104 - accuracy: 0.9900
# Epoch 20/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6660 - accuracy: 0.9900
# Epoch 21/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6224 - accuracy: 0.9900
# Epoch 22/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5731 - accuracy: 0.9900
# Epoch 23/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.5351 - accuracy: 0.9850
# Epoch 24/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4935 - accuracy: 0.9900
# Epoch 25/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4586 - accuracy: 0.9900
# Epoch 26/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.4243 - accuracy: 0.9900
# Epoch 27/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3959 - accuracy: 0.9900
# Epoch 28/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3624 - accuracy: 0.9900
# Epoch 29/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3390 - accuracy: 0.9900
# Epoch 30/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.3148 - accuracy: 0.9900
# Epoch 31/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2933 - accuracy: 0.9900
# Epoch 32/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2722 - accuracy: 0.9900
# Epoch 33/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2574 - accuracy: 0.9900
# Epoch 34/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2398 - accuracy: 0.9900
# Epoch 35/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.2234 - accuracy: 0.9900
# Epoch 36/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2143 - accuracy: 0.9900
# Epoch 37/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1973 - accuracy: 0.9900
# Epoch 38/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1864 - accuracy: 0.9850
# Epoch 39/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1825 - accuracy: 0.9900
# Epoch 40/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1689 - accuracy: 0.9850
# Epoch 41/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1597 - accuracy: 0.9900
# Epoch 42/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1503 - accuracy: 0.9900
# Epoch 43/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1435 - accuracy: 0.9900
# Epoch 44/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1363 - accuracy: 0.9900
# Epoch 45/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1330 - accuracy: 0.9900
# Epoch 46/50
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9900
# Epoch 47/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1208 - accuracy: 0.9900
# Epoch 48/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1131 - accuracy: 0.9900
# Epoch 49/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1089 - accuracy: 0.9900
# Epoch 50/50
# 7/7 [==============================] - 0s 1ms/step - loss: 0.1054 - accuracy: 0.9900
# 2/2 [==============================] - 0s 2ms/step
# c:\Users\Mayank Jaiswal\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 0s 1ms/step
# Epoch 1/100
# 2/2 [==============================] - 1s 191ms/step - loss: 1.3752 - accuracy: 0.2368 - val_loss: 1.5346 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 2/2 [==============================] - 0s 44ms/step - loss: 1.3276 - accuracy: 0.4211 - val_loss: 1.6271 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 2/2 [==============================] - 0s 34ms/step - loss: 1.2908 - accuracy: 0.3684 - val_loss: 1.7157 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 2/2 [==============================] - 0s 35ms/step - loss: 1.2590 - accuracy: 0.4211 - val_loss: 1.7950 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 2/2 [==============================] - 0s 34ms/step - loss: 1.2301 - accuracy: 0.6053 - val_loss: 1.8657 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 2/2 [==============================] - 0s 33ms/step - loss: 1.2025 - accuracy: 0.7105 - val_loss: 1.9366 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 2/2 [==============================] - 0s 47ms/step - loss: 1.1784 - accuracy: 0.7105 - val_loss: 2.0148 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 2/2 [==============================] - 0s 33ms/step - loss: 1.1540 - accuracy: 0.7105 - val_loss: 2.0977 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 2/2 [==============================] - 0s 36ms/step - loss: 1.1343 - accuracy: 0.7105 - val_loss: 2.1755 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 2/2 [==============================] - 0s 34ms/step - loss: 1.1124 - accuracy: 0.7368 - val_loss: 2.2436 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0942 - accuracy: 0.6842 - val_loss: 2.3032 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 2/2 [==============================] - 0s 35ms/step - loss: 1.0735 - accuracy: 0.7105 - val_loss: 2.3517 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 2/2 [==============================] - 0s 40ms/step - loss: 1.0558 - accuracy: 0.7368 - val_loss: 2.4049 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 2/2 [==============================] - 0s 32ms/step - loss: 1.0357 - accuracy: 0.7368 - val_loss: 2.4569 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 2/2 [==============================] - 0s 31ms/step - loss: 1.0201 - accuracy: 0.7368 - val_loss: 2.4946 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9997 - accuracy: 0.7895 - val_loss: 2.5127 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.9850 - accuracy: 0.8158 - val_loss: 2.5340 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.9673 - accuracy: 0.8684 - val_loss: 2.5604 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.9531 - accuracy: 0.8421 - val_loss: 2.5767 - val_accuracy: 0.0000e+00
# Epoch 20/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.9349 - accuracy: 0.8684 - val_loss: 2.5705 - val_accuracy: 0.0000e+00
# Epoch 21/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.9187 - accuracy: 0.8158 - val_loss: 2.5585 - val_accuracy: 0.0000e+00
# Epoch 22/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.9005 - accuracy: 0.8158 - val_loss: 2.5473 - val_accuracy: 0.0000e+00
# Epoch 23/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8845 - accuracy: 0.8421 - val_loss: 2.5160 - val_accuracy: 0.0000e+00
# Epoch 24/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.8662 - accuracy: 0.8947 - val_loss: 2.4691 - val_accuracy: 0.0000e+00
# Epoch 25/100
# 2/2 [==============================] - 0s 45ms/step - loss: 0.8494 - accuracy: 0.8684 - val_loss: 2.4410 - val_accuracy: 0.0000e+00
# Epoch 26/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.8346 - accuracy: 0.8947 - val_loss: 2.4289 - val_accuracy: 0.0000e+00
# Epoch 27/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.8180 - accuracy: 0.8947 - val_loss: 2.4294 - val_accuracy: 0.0000e+00
# Epoch 28/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.8039 - accuracy: 0.8684 - val_loss: 2.4249 - val_accuracy: 0.0000e+00
# Epoch 29/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7861 - accuracy: 0.8947 - val_loss: 2.4105 - val_accuracy: 0.0000e+00
# Epoch 30/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7713 - accuracy: 0.8947 - val_loss: 2.4085 - val_accuracy: 0.0000e+00
# Epoch 31/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7581 - accuracy: 0.9211 - val_loss: 2.4159 - val_accuracy: 0.0000e+00
# Epoch 32/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7420 - accuracy: 0.9211 - val_loss: 2.4307 - val_accuracy: 0.0000e+00
# Epoch 33/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7249 - accuracy: 0.9211 - val_loss: 2.4393 - val_accuracy: 0.0000e+00
# Epoch 34/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7058 - accuracy: 0.8947 - val_loss: 2.4371 - val_accuracy: 0.0000e+00
# Epoch 35/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6891 - accuracy: 0.9211 - val_loss: 2.4473 - val_accuracy: 0.0000e+00
# Epoch 36/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6761 - accuracy: 0.8947 - val_loss: 2.4695 - val_accuracy: 0.0000e+00
# Epoch 37/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6699 - accuracy: 0.8158 - val_loss: 2.4981 - val_accuracy: 0.0000e+00
# Epoch 38/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6643 - accuracy: 0.7895 - val_loss: 2.5252 - val_accuracy: 0.0000e+00
# Epoch 39/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6510 - accuracy: 0.7895 - val_loss: 2.5473 - val_accuracy: 0.0000e+00
# Epoch 40/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6341 - accuracy: 0.7895 - val_loss: 2.5557 - val_accuracy: 0.0000e+00
# Epoch 41/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6149 - accuracy: 0.8158 - val_loss: 2.5512 - val_accuracy: 0.0000e+00
# Epoch 42/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5977 - accuracy: 0.8684 - val_loss: 2.5531 - val_accuracy: 0.0000e+00
# Epoch 43/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5826 - accuracy: 0.9211 - val_loss: 2.5586 - val_accuracy: 0.0000e+00
# Epoch 44/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5720 - accuracy: 0.9211 - val_loss: 2.5677 - val_accuracy: 0.0000e+00
# Epoch 45/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5615 - accuracy: 0.9211 - val_loss: 2.5805 - val_accuracy: 0.0000e+00
# Epoch 46/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5501 - accuracy: 0.9211 - val_loss: 2.5964 - val_accuracy: 0.0000e+00
# Epoch 47/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5398 - accuracy: 0.9474 - val_loss: 2.6115 - val_accuracy: 0.0000e+00
# Epoch 48/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5286 - accuracy: 0.9211 - val_loss: 2.6234 - val_accuracy: 0.0000e+00
# Epoch 49/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5184 - accuracy: 0.8947 - val_loss: 2.6382 - val_accuracy: 0.0000e+00
# Epoch 50/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5089 - accuracy: 0.8947 - val_loss: 2.6540 - val_accuracy: 0.0000e+00
# Epoch 51/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.5001 - accuracy: 0.9474 - val_loss: 2.6522 - val_accuracy: 0.0000e+00
# Epoch 52/100
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4908 - accuracy: 0.9474 - val_loss: 2.6275 - val_accuracy: 0.0000e+00
# Epoch 53/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4839 - accuracy: 0.9474 - val_loss: 2.6068 - val_accuracy: 0.0000e+00
# Epoch 54/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4759 - accuracy: 0.9474 - val_loss: 2.5848 - val_accuracy: 0.0000e+00
# Epoch 55/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4678 - accuracy: 0.9474 - val_loss: 2.5635 - val_accuracy: 0.0000e+00
# Epoch 56/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4558 - accuracy: 0.9474 - val_loss: 2.5332 - val_accuracy: 0.0000e+00
# Epoch 57/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4495 - accuracy: 0.9211 - val_loss: 2.5075 - val_accuracy: 0.0000e+00
# Epoch 58/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4417 - accuracy: 0.9211 - val_loss: 2.4819 - val_accuracy: 0.0000e+00
# Epoch 59/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4383 - accuracy: 0.9211 - val_loss: 2.4452 - val_accuracy: 0.0000e+00
# Epoch 60/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4301 - accuracy: 0.8947 - val_loss: 2.4169 - val_accuracy: 0.0000e+00
# Epoch 61/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4206 - accuracy: 0.9211 - val_loss: 2.3939 - val_accuracy: 0.0000e+00
# Epoch 62/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4095 - accuracy: 0.9211 - val_loss: 2.3719 - val_accuracy: 0.0000e+00
# Epoch 63/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4017 - accuracy: 0.9474 - val_loss: 2.3469 - val_accuracy: 0.0000e+00
# Epoch 64/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3942 - accuracy: 0.9474 - val_loss: 2.3209 - val_accuracy: 0.0000e+00
# Epoch 65/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3888 - accuracy: 0.9211 - val_loss: 2.3041 - val_accuracy: 0.0000e+00
# Epoch 66/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3819 - accuracy: 0.9211 - val_loss: 2.2782 - val_accuracy: 0.0000e+00
# Epoch 67/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3771 - accuracy: 0.9474 - val_loss: 2.2191 - val_accuracy: 0.0000e+00
# Epoch 68/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3708 - accuracy: 0.9474 - val_loss: 2.1689 - val_accuracy: 0.0000e+00
# Epoch 69/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3678 - accuracy: 0.9474 - val_loss: 2.1167 - val_accuracy: 0.0000e+00
# Epoch 70/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3651 - accuracy: 0.9211 - val_loss: 2.0665 - val_accuracy: 0.0000e+00
# Epoch 71/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3593 - accuracy: 0.9211 - val_loss: 2.0404 - val_accuracy: 0.0000e+00
# Epoch 72/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3538 - accuracy: 0.9474 - val_loss: 2.0303 - val_accuracy: 0.0000e+00
# Epoch 73/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3486 - accuracy: 0.9474 - val_loss: 2.0459 - val_accuracy: 0.0000e+00
# Epoch 74/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3422 - accuracy: 0.9474 - val_loss: 2.0694 - val_accuracy: 0.0000e+00
# Epoch 75/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3321 - accuracy: 0.9474 - val_loss: 2.0808 - val_accuracy: 0.0000e+00
# Epoch 76/100
# 2/2 [==============================] - 0s 57ms/step - loss: 0.3230 - accuracy: 0.9474 - val_loss: 2.1230 - val_accuracy: 0.0000e+00
# Epoch 77/100
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3177 - accuracy: 0.9474 - val_loss: 2.1889 - val_accuracy: 0.0000e+00
# Epoch 78/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3191 - accuracy: 0.9474 - val_loss: 2.2310 - val_accuracy: 0.0000e+00
# Epoch 79/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3158 - accuracy: 0.9474 - val_loss: 2.2331 - val_accuracy: 0.0000e+00
# Epoch 80/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3106 - accuracy: 0.9474 - val_loss: 2.2316 - val_accuracy: 0.0000e+00
# Epoch 81/100
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3048 - accuracy: 0.9474 - val_loss: 2.2577 - val_accuracy: 0.0000e+00
# Epoch 82/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2994 - accuracy: 0.9474 - val_loss: 2.2882 - val_accuracy: 0.0000e+00
# Epoch 83/100
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2943 - accuracy: 0.9474 - val_loss: 2.2922 - val_accuracy: 0.0000e+00
# Epoch 84/100
# 2/2 [==============================] - 0s 40ms/step - loss: 0.2882 - accuracy: 0.9474 - val_loss: 2.2871 - val_accuracy: 0.0000e+00
# Epoch 85/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2817 - accuracy: 0.9474 - val_loss: 2.2781 - val_accuracy: 0.0000e+00
# Epoch 86/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2807 - accuracy: 0.9474 - val_loss: 2.2547 - val_accuracy: 0.0000e+00
# Epoch 87/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2799 - accuracy: 0.9474 - val_loss: 2.2269 - val_accuracy: 0.0000e+00
# Epoch 88/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2726 - accuracy: 0.9474 - val_loss: 2.2214 - val_accuracy: 0.0000e+00
# Epoch 89/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2649 - accuracy: 0.9474 - val_loss: 2.2274 - val_accuracy: 0.0000e+00
# Epoch 90/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.2629 - accuracy: 0.9474 - val_loss: 2.2521 - val_accuracy: 0.0000e+00
# Epoch 91/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2675 - accuracy: 0.9474 - val_loss: 2.3025 - val_accuracy: 0.0000e+00
# Epoch 92/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2750 - accuracy: 0.9474 - val_loss: 2.3396 - val_accuracy: 0.0000e+00
# Epoch 93/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2750 - accuracy: 0.9474 - val_loss: 2.3423 - val_accuracy: 0.0000e+00
# Epoch 94/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2679 - accuracy: 0.9474 - val_loss: 2.3266 - val_accuracy: 0.0000e+00
# Epoch 95/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2524 - accuracy: 0.9737 - val_loss: 2.2572 - val_accuracy: 0.0000e+00
# Epoch 96/100
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2408 - accuracy: 0.9737 - val_loss: 2.1322 - val_accuracy: 0.0000e+00
# Epoch 97/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2426 - accuracy: 0.9737 - val_loss: 2.0198 - val_accuracy: 0.0000e+00
# Epoch 98/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.2490 - accuracy: 0.9737 - val_loss: 1.9333 - val_accuracy: 0.1000
# Epoch 99/100
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2474 - accuracy: 0.9737 - val_loss: 1.8600 - val_accuracy: 0.1000
# Epoch 100/100
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2381 - accuracy: 0.9737 - val_loss: 1.8302 - val_accuracy: 0.1000
# 2/2 [==============================] - 0s 5ms/step
# c:\Users\Mayank Jaiswal\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import LabelEncoder

# Load the input data for prediction
input_data_generic = [2, 3, 3, 0, 2, 0, 2, 1, 2, 0, 1, 2, 0, 0, 2, 0, 0, 2, 1, 0]
input_data_parallel_1 = [0, 0.66, 0, 0, 0, 0, 0.25, 0, 0, 0.5, 0, 0.25, 0, 0]
input_data_parallel_2 = [0.706181, 0.604714, 0.528406, 0.557752, 0.315469]

# No need to preprocess input data for lists, as they are not Pandas DataFrames

# Load the trained models
model_generic = tf.keras.models.load_model("model_generic.h5")
model_parallel_1 = tf.keras.models.load_model("model_parallel_1.h5")
model_parallel_2 = tf.keras.models.load_model("model_parallel_2.h5")
model_combined = tf.keras.models.load_model("model_combined.h5")

# Convert lists to numpy arrays for compatibility with TensorFlow
X_input_generic = tf.constant([input_data_generic], dtype=tf.float32)
X_input_parallel_1 = tf.constant([input_data_parallel_1], dtype=tf.float32)
X_input_parallel_2 = tf.constant([input_data_parallel_2], dtype=tf.float32)

# Make predictions using individual models
predictions_generic = model_generic.predict(X_input_generic)
predictions_parallel_1 = model_parallel_1.predict(X_input_parallel_1)
predictions_parallel_2 = model_parallel_2.predict(X_input_parallel_2)

# Combine the outputs of parallel AI 1 and AI 2 for the third AI
combined_input = tf.keras.layers.Concatenate()([predictions_parallel_1, predictions_parallel_2])

# Make predictions using the combined model
predictions_combined = model_combined.predict(combined_input)

your_original_labels_for_generic = ['Engineering']
your_original_labels_for_parallel_1 = ['Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering']
your_original_labels_for_parallel_2 = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering']
your_original_labels_for_combined = [ 'Computer Science and Engineering (including specializations) / Information Technology', 'Electronics and Communication Engineering', 'Mechanical Engineering', 'Civil Engineering', '1']

# Create and fit LabelEncoders for each model's predictions
label_decoder_generic = LabelEncoder()
label_decoder_generic.fit(your_original_labels_for_generic)  # Replace with your actual labels
label_decoder_parallel_1 = LabelEncoder()
label_decoder_parallel_1.fit(your_original_labels_for_parallel_1)  # Replace with your actual labels
label_decoder_parallel_2 = LabelEncoder()
label_decoder_parallel_2.fit(your_original_labels_for_parallel_2)  # Replace with your actual labels
label_decoder_combined = LabelEncoder()
label_decoder_combined.fit(your_original_labels_for_combined)  # Replace with your actual labels

# Inverse transform the predictions to get the original labels
predicted_labels_generic = label_decoder_generic.inverse_transform(tf.argmax(predictions_generic, axis=1).numpy())
predicted_labels_parallel_1 = label_decoder_parallel_1.inverse_transform(tf.argmax(predictions_parallel_1, axis=1).numpy())
predicted_labels_parallel_2 = label_decoder_parallel_2.inverse_transform(tf.argmax(predictions_parallel_2, axis=1).numpy())
predicted_labels_combined = label_decoder_combined.inverse_transform(tf.argmax(predictions_combined, axis=1).numpy())

# Print or use the predicted labels as needed
print("Predicted Labels - Generic AI:", predicted_labels_generic)
print("Predicted Labels - Parallel AI 1:", predicted_labels_parallel_1)
print("Predicted Labels - Parallel AI 2:", predicted_labels_parallel_2)
print("Predicted Labels - Combined AI:", predicted_labels_combined)

# Assuming you have a dataset like this
# Note: This is just a sample, replace it with your actual dataset
college_exam_data = {
    'Computer Science and Engineering (including specializations) / Information Technology': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'IIT Kharagpur', 'Bits Pilani'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']
    },
    'Electronics and Communication Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'Bits Pilani', 'NIT Trichy'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']
    },
    'Mechanical Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Roorky', 'IIT Guwahati', 'BITS Hyderabad'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']

    },
    'Civil Engineering': {
        'colleges': ['IIT Madras', 'IIT Delhi', 'IIT Bombay', 'IIT Kanpur', 'IIT BHU'],
        'exams': ['JEE Mains', 'JEE Advance', 'BITSAT'],
        'resources': ['Geeks for Geeks: https://www.geeksforgeeks.org/', 'CodeChef: https://www.codechef.com/', 'Coursera: https://www.coursera.org/en-IN']

    }
}

def get_college_exam_info(predicted_label):
    return college_exam_data.get(predicted_label, {'colleges': [], 'exams': []})

# Example usage:
predicted_label_combined = predicted_labels_combined[0]  # Assuming it's a single prediction
info = get_college_exam_info(predicted_label_combined)

print(f"Prediction: {predicted_label_combined}")
print("Colleges:")
for college in info['colleges']:
    print(f"  - {college}")
print("Entrance Exams:")
for exam in info['exams']:
    print(f"  - {exam}")
print("Resources:")
for res in info['resources']:
    print(f"  - {res}")
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 69ms/step
# Predicted Labels - Generic AI: ['Engineering']
# Predicted Labels - Parallel AI 1: ['Electronics and Communication Engineering']
# Predicted Labels - Parallel AI 2: ['Computer Science and Engineering (including specializations) / Information Technology']
# Predicted Labels - Combined AI: ['Computer Science and Engineering (including specializations) / Information Technology']
# Prediction: Computer Science and Engineering (including specializations) / Information Technology
# Colleges:
#   - IIT Madras
#   - IIT Delhi
#   - IIT Bombay
#   - IIT Kharagpur
#   - Bits Pilani
# Entrance Exams:
#   - JEE Mains
#   - JEE Advance
#   - BITSAT
# Resources:
#   - Geeks for Geeks: https://www.geeksforgeeks.org/
#   - CodeChef: https://www.codechef.com/
#   - Coursera: https://www.coursera.org/en-IN
